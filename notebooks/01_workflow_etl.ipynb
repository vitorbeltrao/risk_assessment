# %% [markdown]
# # ETL Pipeline

# %% [markdown]
# ## Collect Data

# %%
# import necessary packages
import pandas as pd

# %%
# import the dataset as a pandas dataframe
pdf_one = pd.read_csv('dataset3.csv')
pdf_two = pd.read_csv('dataset4.csv')

# %% [markdown]
# ## A quick look in data structure

# %%
# see the five first entries of the dataset
pdf_one.head()
# Out:
#   corporation  lastmonth_activity  lastyear_activity  number_of_employees  \
# 0        nciw                  45                  0                   99
# 1        lsid                  36                234                  541
# 2        pwls                  23                555                   23
# 3        bqlx                  15                 11                  190
# 4        zmei                 100               2929                  999
#
#    exited
# 0       1
# 1       0
# 2       0
# 3       1
# 4       1

# %%
# see the five first entries of the dataset
pdf_two.head()
# Out:
#   corporation  lastmonth_activity  lastyear_activity  number_of_employees  \
# 0        abcd                  99                871                    3
# 1        asdf                1243                  0                   10
# 2        xyzz                   0                 25                   11
# 3        acme                 813                129                    9
# 4        qwer                2989               9982                   90
#
#    exited
# 0       0
# 1       0
# 2       1
# 3       1
# 4       0

# %%
# verify the size type and null data
pdf_one.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   corporation          11 non-null     object
#  1   lastmonth_activity   11 non-null     int64
#  2   lastyear_activity    11 non-null     int64
#  3   number_of_employees  11 non-null     int64
#  4   exited               11 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 568.0+ bytes

# %%
# verify the size type and null data
pdf_two.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   corporation          15 non-null     object
#  1   lastmonth_activity   15 non-null     int64
#  2   lastyear_activity    15 non-null     int64
#  3   number_of_employees  15 non-null     int64
#  4   exited               15 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 728.0+ bytes

# %% [markdown]
# ## ETL Pipeline

# %%
# 1. Merge the datasets
train_df = pdf_one.merge(
    pdf_two, 
    how='outer', 
    on=list(pdf_one.columns))
# Out:
#    corporation  lastmonth_activity  lastyear_activity  number_of_employees  \
# 0         nciw                  45                  0                   99
# 1         lsid                  36                234                  541
# 2         pwls                  23                555                   23
# 3         bqlx                  15                 11                  190
# 4         zmei                 100               2929                  999
# 5         wosl                   2                  1                 1359
# 6         xcvb                   0                 14                  282
# 7         dfgh                 500                 40                  949
# 8         ngrd                1234                103                 3782
# 9         xful               98765                  7                  655
# 10        kshe                  34               2345                   18
# 11        abcd                  99                871                    3
# 12        asdf                1243                  0                   10
# 13        xyzz                   0                 25                   11
# 14        acme                 813                129                    9
# 15        qwer                2989               9982                   90
# 16        tyui                 395                190                   99
# 17        zxcv               19028                999                   81
# 18        hjkl                 345                 78                    2
# 19        lmno                1024                 14                    3
# 20        qqqq                2145                182                  110
# 21        corp                3891                101                  998
# 22        ekci               10983                  0                 1200
# 23        dosk                 118                929                   81
# 24        endi                1992                 19                    2
# 25        gudj                 455                 94                  298
#
#     exited
# 0        1
# 1        0
# 2        0
# 3        1
# 4        1
# 5        0
# 6        1
# 7        0
# 8        1
# 9        0
# 10       1
# 11       0
# 12       0
# 13       1
# 14       1
# 15       0
# 16       0
# 17       0
# 18       1
# 19       1
# 20       1
# 21       0
# 22       0
# 23       1
# 24       0
# 25       1

# %%
# 2. drop duplicated rows
train_df.drop_duplicates(inplace=True)
# Out:
#    corporation  lastmonth_activity  lastyear_activity  number_of_employees  \
# 0         nciw                  45                  0                   99
# 1         lsid                  36                234                  541
# 2         pwls                  23                555                   23
# 3         bqlx                  15                 11                  190
# 4         zmei                 100               2929                  999
# 5         wosl                   2                  1                 1359
# 6         xcvb                   0                 14                  282
# 7         dfgh                 500                 40                  949
# 8         ngrd                1234                103                 3782
# 9         xful               98765                  7                  655
# 10        kshe                  34               2345                   18
# 11        abcd                  99                871                    3
# 12        asdf                1243                  0                   10
# 13        xyzz                   0                 25                   11
# 14        acme                 813                129                    9
# 15        qwer                2989               9982                   90
# 16        tyui                 395                190                   99
# 17        zxcv               19028                999                   81
# 18        hjkl                 345                 78                    2
# 19        lmno                1024                 14                    3
# 20        qqqq                2145                182                  110
# 21        corp                3891                101                  998
# 22        ekci               10983                  0                 1200
# 23        dosk                 118                929                   81
# 24        endi                1992                 19                    2
# 25        gudj                 455                 94                  298
#
#     exited
# 0        1
# 1        0
# 2        0
# 3        1
# 4        1
# 5        0
# 6        1
# 7        0
# 8        1
# 9        0
# 10       1
# 11       0
# 12       0
# 13       1
# 14       1
# 15       0
# 16       0
# 17       0
# 18       1
# 19       1
# 20       1
# 21       0
# 22       0
# 23       1
# 24       0
# 25       1
